# %%
# %run mnist.py
# Out:
# GPU: -1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/tsuruoka/introduction_to_deep_learning/mnist.py in <module>()
#     127
#     128 if __name__ == '__main__':
# --> 129     main()
#
# /Users/tsuruoka/introduction_to_deep_learning/mnist.py in main()
#      97
#      98     # Save two plot images to the result dir
# ---> 99     if extensions.PlotReport.available():
#     100         trainer.extend(
#     101             extensions.PlotReport(['main/loss', 'validation/main/loss'],
#
# AttributeError: type object 'PlotReport' has no attribute 'available'

# %%
# !pip install --upgrade chainer
# Out:
# ...
#     100% |████████████████████████████████| 1.5MB 395kB/s eta 0:00:01
# Requirement already up-to-date: filelock in /Users/tsuruoka/.pyenv/versions/anaconda3-2.4.0/envs/jupyter/lib/python3.5/site-packages (from chainer)
# Requirement already up-to-date: nose in /Users/tsuruoka/.pyenv/versions/anaconda3-2.4.0/envs/jupyter/lib/python3.5/site-packages (from chainer)
# ...
#     100% |████████████████████████████████| 4.4MB 151kB/s eta 0:00:01
# Requirement already up-to-date: protobuf in /Users/tsuruoka/.pyenv/versions/anaconda3-2.4.0/envs/jupyter/lib/python3.5/site-packages (from chainer)
# Requirement already up-to-date: six>=1.9.0 in /Users/tsuruoka/.pyenv/versions/anaconda3-2.4.0/envs/jupyter/lib/python3.5/site-packages (from chainer)
# ...
#     100% |████████████████████████████████| 399kB 1.5MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 4.2MB/s ta 0:00:01
# ...
# done
# ...

# %%
# %run mnist.py
# Out:
# GPU: -1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/tsuruoka/introduction_to_deep_learning/mnist.py in <module>()
#     127
#     128 if __name__ == '__main__':
# --> 129     main()
#
# /Users/tsuruoka/introduction_to_deep_learning/mnist.py in main()
#      97
#      98     # Save two plot images to the result dir
# ---> 99     if extensions.PlotReport.available():
#     100         trainer.extend(
#     101             extensions.PlotReport(['main/loss', 'validation/main/loss'],
#
# AttributeError: type object 'PlotReport' has no attribute 'available'

# %%
# %run mnist.py
# Out:
# GPU: -1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     17.204 iters/sec. Estimated time to finish: 0:11:25.882202.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     14.772 iters/sec. Estimated time to finish: 0:13:12.014723.
#      total [#.................................................]  3.33%
# ...
